# %%
import matplotlib.pyplot as plt
from pr1 import main
import math

# %%
pi1, delta1, pi2, delta2, integrals, delta3 = main()

plt.plot(pi1, label="task 2")
plt.plot(pi2, label="task 3")
plt.axhline(y=math.pi, color="r", linestyle="--", label="pi")
plt.legend()

# %%
plt.plot(delta1, label="task 2")
plt.plot(delta2, label="task 3")
plt.legend()

# %%
plt.plot(integrals, label="integrals")
plt.axhline(y=6, color="r", linestyle="-", label="real value")
plt.legend()

# %%
plt.plot(delta3)
